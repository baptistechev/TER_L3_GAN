# %%
# pour monter son drive Google Drive local
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/Colab Notebooks
# %ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Colab Notebooks
# '1_-_Classification_de_donnees (1).ipynb'
# '1_-_Classification_de_donnees (2).ipynb'
#  1_-_Classification_de_donnees.ipynb
# '2_-_Ingenierie_des_donnees_textuelles_solutionsintegrees (1).ipynb'
#  2_-_Ingenierie_des_donnees_textuelles_solutionsintegrees.ipynb
#  3_-_Classification_de_donnees_textuelles.ipynb
#  6_-_Les_word_embeddings_solutionsintegrees.ipynb
#  LSTMForGeneratingText.ipynb
#  LSTMForGeneratingText-VersioCommente.ipynb
#  positive.review
#  SPOILER_4_-_Utiliser_un_modele_solutionsintegrees.ipynb
#  testdata.manual.2009.06.14.csv
#  training.1600000.processed.noemoticon.csv
#  Untitled0.ipynb
#  weights-improvement-50-1.2016-bigger.hdf5
#  wonderland.txt

# %%
import pandas as pd

df = pd.read_csv("training.1600000.processed.noemoticon.csv",names=["sentiment", "index", "date", "subject", "sender","sentence"],sep=',', encoding='latin-1')
display(df[df.sentiment == 4])
# Out:
#          sentiment  ...                                           sentence
# 800000           4  ...       I LOVE @Health4UandPets u guys r the best!!
# 800001           4  ...  im meeting up with one of my besties tonight! ...
# 800002           4  ...  @DaRealSunisaKim Thanks for the Twitter add, S...
# 800003           4  ...  Being sick can be really cheap when it hurts t...
# 800004           4  ...    @LovesBrooklyn2 he has that effect on everyone
# ...            ...  ...                                                ...
# 1599995          4  ...  Just woke up. Having no school is the best fee...
# 1599996          4  ...  TheWDB.com - Very cool to hear old Walt interv...
# 1599997          4  ...  Are you ready for your MoJo Makeover? Ask me f...
# 1599998          4  ...  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999          4  ...  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [800000 rows x 6 columns]
